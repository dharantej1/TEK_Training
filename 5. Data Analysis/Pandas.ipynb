# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
s0=pd.Series([24,25,26,27],index=[1,2,3,4])
s0
# Out:
# 1    24
# 2    25
# 3    26
# 4    27
# dtype: int64

# %%
s0.index
# Out:
# Int64Index([1, 2, 3, 4], dtype='int64')

# %%
print(s0[1])
# Out:
# 24

# %%
s0[[2,1,3]]
# Out:
# 2    25
# 1    24
# 3    26
# dtype: int64

# %%
print(s0[s0>0])
print(s0*2)
# Out:
# 1    24
# 2    25
# 3    26
# 4    27
# dtype: int64
# 1    48
# 2    50
# 3    52
# 4    54
# dtype: int64

# %%
np.exp(s0)
# Out:
# 1    2.648912e+10
# 2    7.200490e+10
# 3    1.957296e+11
# 4    5.320482e+11
# dtype: float64

# %%
'b' in s0
# Out:
# False

# %%
1 in s0
# Out:
# True

# %%
sdata={
    'TN': 35000,
    'TR': 71000,
    'AN': 16000,
    'UP': 5000
}
diSer=pd.Series(sdata)
print(diSer)
# Out:
# TN    35000
# TR    71000
# AN    16000
# UP     5000
# dtype: int64

# %%
states=['TN','AP','AN','KA']
s4=pd.Series(sdata, index=states)
s4
# Out:
# TN    35000.0
# AP        NaN
# AN    16000.0
# KA        NaN
# dtype: float64

# %%
pd.notnull(s4)
# Out:
# TN     True
# AP    False
# AN     True
# KA    False
# dtype: bool

# %%
pd.isnull(s4)
# Out:
# TN    False
# AP     True
# AN    False
# KA     True
# dtype: bool

# %%
s4.name='population'
s4.index.name='state'
s4
# Out:
# state
# TN    35000.0
# AP        NaN
# AN    16000.0
# KA        NaN
# Name: population, dtype: float64

# %%
s4.name
# Out:
# 'population'

# %%
data={
    'name':['babloo', 'tinku', 'tina', 'janardhan', 'abhi', 'vanita', 'kalia'],
    'score':[1,2,3,4,5,6,7],
    'subject':['kushti', 'dancing', 'singing', 'swimming', 'tennis', 'karate', 'surfing'],
    'gender': ['M','M','M','M','F','F','F']
}
df =pd.Series(data)
df
# Out:
# name       [babloo, tinku, tina, janardhan, abhi, vanita,...
# score                                  [1, 2, 3, 4, 5, 6, 7]
# subject    [kushti, dancing, singing, swimming, tennis, k...
# gender                                 [M, M, M, M, F, F, F]
# dtype: object

# %%
data={
    'name':['babloo', 'tinku', 'tina', 'janardhan', 'abhi', 'vanita', 'kalia'],
    'score':[10,20,30,40,50,60,70],
    'subject':['kushti', 'dancing', 'singing', 'swimming', 'tennis', 'karate', 'surfing'],
    'gender': ['M','M','M','M','F','F','F']
}
df =pd.DataFrame(data)
df
# Out:
#         name  score   subject gender
# 0     babloo     10    kushti      M
# 1      tinku     20   dancing      M
# 2       tina     30   singing      M
# 3  janardhan     40  swimming      M
# 4       abhi     50    tennis      F
# 5     vanita     60    karate      F
# 6      kalia     70   surfing      F

# %%
df = pd.DataFrame(data, columns=['name', 'score', 'gender','subject'])
df
# Out:
#         name  score gender   subject
# 0     babloo     10      M    kushti
# 1      tinku     20      M   dancing
# 2       tina     30      M   singing
# 3  janardhan     40      M  swimming
# 4       abhi     50      F    tennis
# 5     vanita     60      F    karate
# 6      kalia     70      F   surfing

# %%
df
# Out:
#         name  score gender   subject
# 0     babloo     10      M    kushti
# 1      tinku     20      M   dancing
# 2       tina     30      M   singing
# 3  janardhan     40      M  swimming
# 4       abhi     50      F    tennis
# 5     vanita     60      F    karate
# 6      kalia     70      F   surfing

# %%
df.head()
# Out:
#         name  score gender   subject
# 0     babloo     10      M    kushti
# 1      tinku     20      M   dancing
# 2       tina     30      M   singing
# 3  janardhan     40      M  swimming
# 4       abhi     50      F    tennis

# %%
df.tail()
# Out:
#         name  score gender   subject
# 2       tina     30      M   singing
# 3  janardhan     40      M  swimming
# 4       abhi     50      F    tennis
# 5     vanita     60      F    karate
# 6      kalia     70      F   surfing

# %%
df.head(2)
# Out:
#      name  score gender  subject
# 0  babloo     10      M   kushti
# 1   tinku     20      M  dancing

# %%
df = pd.DataFrame(data, columns=['name', 'score', 'age', 'gender','subject', 'area'])
df
# Out:
#         name  score  age gender   subject area
# 0     babloo     10  NaN      M    kushti  NaN
# 1      tinku     20  NaN      M   dancing  NaN
# 2       tina     30  NaN      M   singing  NaN
# 3  janardhan     40  NaN      M  swimming  NaN
# 4       abhi     50  NaN      F    tennis  NaN
# 5     vanita     60  NaN      F    karate  NaN
# 6      kalia     70  NaN      F   surfing  NaN

# %%
df=pd.DataFrame(data, columns=['name', 'score', 'age', 'gender','subject', 'area'], index=['one', 'two', 'three', 'four', 'five', 'six', 'seven'])
df
# Out:
#             name  score  age gender   subject area
# one       babloo     10  NaN      M    kushti  NaN
# two        tinku     20  NaN      M   dancing  NaN
# three       tina     30  NaN      M   singing  NaN
# four   janardhan     40  NaN      M  swimming  NaN
# five        abhi     50  NaN      F    tennis  NaN
# six       vanita     60  NaN      F    karate  NaN
# seven      kalia     70  NaN      F   surfing  NaN

# %%
df[['name','subject']]
# Out:
#             name   subject
# one       babloo    kushti
# two        tinku   dancing
# three       tina   singing
# four   janardhan  swimming
# five        abhi    tennis
# six       vanita    karate
# seven      kalia   surfing

# %%
df.subject
# Out:
# one        kushti
# two       dancing
# three     singing
# four     swimming
# five       tennis
# six        karate
# seven     surfing
# Name: subject, dtype: object

# %%
df.loc[['one']]
# Out:
#        name  score  age gender subject area
# one  babloo     10  NaN      M  kushti  NaN

# %%
df.loc['one']
# Out:
# name       babloo
# score          10
# age           NaN
# gender          M
# subject    kushti
# area          NaN
# Name: one, dtype: object

# %%
df.loc[['six','one']]
# Out:
#        name  score  age gender subject area
# six  vanita     60  NaN      F  karate  NaN
# one  babloo     10  NaN      M  kushti  NaN

# %%
df.loc[(df['gender']=='F') & (df['score']==50)].head()
# Out:
#       name  score  age gender subject area
# five  abhi     50  NaN      F  tennis  NaN

# %%
df['age']=18
df
# Out:
#             name  score  age gender   subject area
# one       babloo     10   18      M    kushti  NaN
# two        tinku     20   18      M   dancing  NaN
# three       tina     30   18      M   singing  NaN
# four   janardhan     40   18      M  swimming  NaN
# five        abhi     50   18      F    tennis  NaN
# six       vanita     60   18      F    karate  NaN
# seven      kalia     70   18      F   surfing  NaN

# %%
df['pass']=df['score']>30
df
# Out:
#             name  score  age gender   subject area   pass
# one       babloo     10   18      M    kushti  NaN  False
# two        tinku     20   18      M   dancing  NaN  False
# three       tina     30   18      M   singing  NaN  False
# four   janardhan     40   18      M  swimming  NaN   True
# five        abhi     50   18      F    tennis  NaN   True
# six       vanita     60   18      F    karate  NaN   True
# seven      kalia     70   18      F   surfing  NaN   True

# %%
del df['pass']
df
# Out:
#             name  score  age gender   subject area
# one       babloo     10   18      M    kushti  NaN
# two        tinku     20   18      M   dancing  NaN
# three       tina     30   18      M   singing  NaN
# four   janardhan     40   18      M  swimming  NaN
# five        abhi     50   18      F    tennis  NaN
# six       vanita     60   18      F    karate  NaN
# seven      kalia     70   18      F   surfing  NaN

# %%
df.iloc[0,0]
# Out:
# 'babloo'

# %%
df.iloc[:2,:3]
# Out:
#        name  score  age
# one  babloo     10   18
# two   tinku     20   18

# %%
# exercise
# build a dataframe where the column names are subject names (MPC,etc)
# row shall contains the name of the students and each cell should have the marks

data={
    'Maths':[10,20],
    'Physics':[21,22],
    'Chemistry':[1,2],
    'Telugu':[1,2],
    'Hindi':[1,2]
}
df=pd.DataFrame(data,columns=['Maths', 'Physics', 'Chemistry', 'Telugu', 'Hindi'],index=['Dharan', 'Harsh'])
df
# Out:
#         Maths  Physics  Chemistry  Telugu  Hindi
# Dharan     10       21          1       1      1
# Harsh      20       22          2       2      2

# %% [markdown]
# # Pd from csv

# %%
ipl=pd.read_csv('./matches_01.csv')
ipl_new=pd.read_csv('./matches_02.csv')

# %%
print(ipl.shape)
print(ipl_new.shape)
# Out:
# (577, 19)
# (59, 19)

# %%
print(ipl.columns==ipl_new.columns)
# Out:
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True]

# %%
ipl_final=ipl.copy()
ipl_final=pd.concat([ipl_final,ipl_new])
print(ipl_final.shape)
# Out:
# (636, 19)

# %%
ipl_final.head()
# Out:
#   match_id  season        city        date team1_id team2_id toss_winner  \
# 0   2008_1    2008   Bangalore  18-04-2008      KKR      RCB         RCB
# 1   2008_2    2008  Chandigarh  19-04-2008      CSK      KXI         CSK
# 2   2008_3    2008       Delhi  19-04-2008       RR       DD          RR
# 3   2008_4    2008      Mumbai  20-04-2008       MI      RCB          MI
# 4   2008_5    2008     Kolkata  20-04-2008       DC      KKR          DC
#
#   toss_decision  result  dl_applied winner  win_by_runs  win_by_wickets  \
# 0         field  normal           0    KKR          140               0
# 1           bat  normal           0    CSK           33               0
# 2           bat  normal           0     DD            0               9
# 3           bat  normal           0    RCB            0               5
# 4           bat  normal           0    KKR            0               5
#
#     player_of_match  player_of_match_id  \
# 0  Brendon McCullum                82.0
# ...

# %%
ipl_final.dtypes
# Out:
# match_id               object
# season                  int64
# city                   object
# date                   object
# team1_id               object
# team2_id               object
# toss_winner            object
# toss_decision          object
# result                 object
# dl_applied              int64
# winner                 object
# win_by_runs             int64
# win_by_wickets          int64
# player_of_match        object
# player_of_match_id    float64
# venue                  object
# venue_id                int64
# umpire1                object
# umpire2                object
# dtype: object

# %%
ipl_final.set_index(['match_id'],inplace=True)
# changing the index to match_id instead of the default 0 to n values

# %%
ipl_final.head()
# Out:
#           season        city        date team1_id team2_id toss_winner  \
# match_id
# 2008_1      2008   Bangalore  18-04-2008      KKR      RCB         RCB
# 2008_2      2008  Chandigarh  19-04-2008      CSK      KXI         CSK
# 2008_3      2008       Delhi  19-04-2008       RR       DD          RR
# 2008_4      2008      Mumbai  20-04-2008       MI      RCB          MI
# 2008_5      2008     Kolkata  20-04-2008       DC      KKR          DC
#
#          toss_decision  result  dl_applied winner  win_by_runs  \
# match_id
# 2008_1           field  normal           0    KKR          140
# 2008_2             bat  normal           0    CSK           33
# 2008_3             bat  normal           0     DD            0
# 2008_4             bat  normal           0    RCB            0
# 2008_5             bat  normal           0    KKR            0
#
#           win_by_wickets   player_of_match  player_of_match_id  \
# match_id
# ...

# %%
ipl_final.describe()
# Out:
#             season  dl_applied  win_by_runs  win_by_wickets  \
# count   636.000000  636.000000   636.000000      636.000000
# mean   2012.490566    0.025157    13.682390        3.372642
# std       2.773026    0.156726    23.908877        3.420338
# min    2008.000000    0.000000     0.000000        0.000000
# 25%    2010.000000    0.000000     0.000000        0.000000
# 50%    2012.000000    0.000000     0.000000        4.000000
# 75%    2015.000000    0.000000    20.000000        7.000000
# max    2017.000000    1.000000   146.000000       10.000000
#
#        player_of_match_id    venue_id
# count          633.000000  636.000000
# mean           209.751975   10.179245
# std            180.132037    9.403096
# min              1.000000    1.000000
# 25%             69.000000    3.000000
# 50%            149.000000    7.000000
# 75%            321.000000   14.000000
# max            691.000000   34.000000

# %%
ipl_final.drop(['venue_id'], axis=1, inplace=True)

# %%
ipl_final.shape
# Out:
# (636, 17)

# %%
ipl_final.drop(['2008_1', '2009_1', '2010_1'], axis=0, inplace=True)
ipl.head()
# Out:
#   match_id  season        city        date team1_id team2_id toss_winner  \
# 0   2008_1    2008   Bangalore  18-04-2008      KKR      RCB         RCB
# 1   2008_2    2008  Chandigarh  19-04-2008      CSK      KXI         CSK
# 2   2008_3    2008       Delhi  19-04-2008       RR       DD          RR
# 3   2008_4    2008      Mumbai  20-04-2008       MI      RCB          MI
# 4   2008_5    2008     Kolkata  20-04-2008       DC      KKR          DC
#
#   toss_decision  result  dl_applied winner  win_by_runs  win_by_wickets  \
# 0         field  normal           0    KKR          140               0
# 1           bat  normal           0    CSK           33               0
# 2           bat  normal           0     DD            0               9
# 3           bat  normal           0    RCB            0               5
# 4           bat  normal           0    KKR            0               5
#
#     player_of_match  player_of_match_id  \
# 0  Brendon McCullum                82.0
# ...

# %%
ipl_final.shape
# Out:
# (633, 17)

# %%
ipl_final['winner'].value_counts()
# Out:
# MI     91
# CSK    79
# KKR    75
# RCB    73
# KXI    70
# RR     63
# DD     62
# SRH    42
# DC     29
# RPS    15
# GL     13
# PW     12
# KTK     6
# Name: winner, dtype: int64

# %%
subset1=ipl_final.loc[:,['venue','winner']]
subset1
# Out:
#                                                       venue winner
# match_id
# 2008_2    I.S. Bindra Punjab Cricket Association Stadium...    CSK
# 2008_3                      Feroz Shah Kotla Stadium, Delhi     DD
# 2008_4                Wankhede Stadium, Mumbai, Maharashtra    RCB
# 2008_5            Eden Garden Stadium, Kolkata, West Bengal    KKR
# 2008_6           Sawai Man Singh Stadium, Jaipur, Rajasthan     RR
# ...                                                     ...    ...
# 2017_55                     Feroz Shah Kotla Stadium, Delhi    RCB
# 2017_56               Wankhede Stadium, Mumbai, Maharashtra    RPS
# 2017_57          M.Chinnaswamy Stadium Bengaluru, Karnataka    KKR
# 2017_58          M.Chinnaswamy Stadium Bengaluru, Karnataka     MI
# 2017_59       Rajiv Gandhi International Stadium, Hyderabad     MI
#
# [633 rows x 2 columns]

# %%
subset2=ipl_final.loc[['2008_2','2009_2','2010_2'],['venue','winner']]

subset2
# Out:
#                                                       venue winner
# match_id
# 2008_2    I.S. Bindra Punjab Cricket Association Stadium...    CSK
# 2009_2                                             Newlands    RCB
# 2010_2                                    Brabourne Stadium     MI

# %%
ipl_final.iloc[50:53,1:5]
# Out:
#                city        date team1_id team2_id
# match_id
# 2008_52   Bangalore  03-05-2008      RCB       DC
# 2008_53     Kolkata  25-05-2008      KXI      KKR
# 2008_54      Jaipur  26-05-2008       MI       RR

# %%
subset3=ipl_final.loc[ipl_final['city']=='Hyderabad',:]
subset3
# Out:
#           season       city        date team1_id team2_id toss_winner  \
# match_id
# 2008_7      2008  Hyderabad  22-04-2008       DC       DD          DC
# 2008_9      2008  Hyderabad  24-04-2008       DC       RR          RR
# 2008_18     2008  Hyderabad  01-05-2008       DC      KXI         KXI
# 2008_21     2008  Hyderabad  25-05-2008       DC      RCB          DC
# 2008_33     2008  Hyderabad  11-05-2008      KKR       DC         KKR
# 2008_43     2008  Hyderabad  18-05-2008       MI       DC          DC
# 2008_55     2008  Hyderabad  27-05-2008       DC      CSK          DC
# 2011_2      2011  Hyderabad  09-04-2011       DC       RR          RR
# 2011_11     2011  Hyderabad  14-04-2011       DC      RCB         RCB
# 2011_15     2011  Hyderabad  16-04-2011       DC      KXI         KXI
# 2011_26     2011  Hyderabad  24-04-2011       MI       DC          DC
# 2011_41     2011  Hyderabad  03-05-2011      KKR       DC          DC
# ...

# %%
subset4=ipl_final.loc[(ipl_final['city']=='Chennai') & (ipl_final['winner']=='CSK'),:].loc[:,['team1_id','team2_id','city','winner']]
subset4
# Out:
#          team1_id team2_id     city winner
# match_id
# 2008_8        CSK       MI  Chennai    CSK
# 2008_12       KKR      CSK  Chennai    CSK
# 2008_32       CSK      KXI  Chennai    CSK
# 2010_28       RCB      CSK  Chennai    CSK
# 2010_32       CSK       RR  Chennai    CSK
# 2010_37       CSK       MI  Chennai    CSK
# 2010_48       KKR      CSK  Chennai    CSK
# 2011_1        CSK      KKR  Chennai    CSK
# 2011_14       CSK      RCB  Chennai    CSK
# 2011_28       CSK       PW  Chennai    CSK
# 2011_38       CSK       DC  Chennai    CSK
# 2011_42        RR      CSK  Chennai    CSK
# 2011_55       CSK       DD  Chennai    CSK
# 2011_63       CSK      KTK  Chennai    CSK
# 2011_73       CSK      RCB  Chennai    CSK
# 2012_13       RCB      CSK  Chennai    CSK
# 2012_25       CSK       PW  Chennai    CSK
# 2012_27        RR      CSK  Chennai    CSK
# 2012_45       CSK       DC  Chennai    CSK
# 2012_57        DD      CSK  Chennai    CSK
# ...

# %%
# or
subset4=ipl_final.loc[(ipl_final['city']=='Chennai') & (ipl_final['winner']=='CSK'),['team1_id','team2_id','city','winner']]
subset4
# Out:
#          team1_id team2_id     city winner
# match_id
# 2008_8        CSK       MI  Chennai    CSK
# 2008_12       KKR      CSK  Chennai    CSK
# 2008_32       CSK      KXI  Chennai    CSK
# 2010_28       RCB      CSK  Chennai    CSK
# 2010_32       CSK       RR  Chennai    CSK
# 2010_37       CSK       MI  Chennai    CSK
# 2010_48       KKR      CSK  Chennai    CSK
# 2011_1        CSK      KKR  Chennai    CSK
# 2011_14       CSK      RCB  Chennai    CSK
# 2011_28       CSK       PW  Chennai    CSK
# 2011_38       CSK       DC  Chennai    CSK
# 2011_42        RR      CSK  Chennai    CSK
# 2011_55       CSK       DD  Chennai    CSK
# 2011_63       CSK      KTK  Chennai    CSK
# 2011_73       CSK      RCB  Chennai    CSK
# 2012_13       RCB      CSK  Chennai    CSK
# 2012_25       CSK       PW  Chennai    CSK
# 2012_27        RR      CSK  Chennai    CSK
# 2012_45       CSK       DC  Chennai    CSK
# 2012_57        DD      CSK  Chennai    CSK
# ...
