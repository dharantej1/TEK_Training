# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('./covid19_details.csv',encoding='ISO-8859-1')
df.head()
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  28/03/2020   28      3  2020     16       1             Afghanistan    AF
# 1  27/03/2020   27      3  2020      0       0             Afghanistan    AF
# 2  26/03/2020   26      3  2020     33       0             Afghanistan    AF
# 3  25/03/2020   25      3  2020      2       0             Afghanistan    AF
# 4  24/03/2020   24      3  2020      6       1             Afghanistan    AF
#
#   countryterritoryCode  popData2018
# 0                  AFG   37172386.0
# 1                  AFG   37172386.0
# 2                  AFG   37172386.0
# 3                  AFG   37172386.0
# 4                  AFG   37172386.0

# %%
df.count()
# Out:
# dateRep                    7320
# day                        7320
# month                      7320
# year                       7320
# cases                      7320
# deaths                     7320
# countriesAndTerritories    7320
# geoId                      7306
# countryterritoryCode       7254
# popData2018                7311
# dtype: int64

# %%
mac_df=df[df['countriesAndTerritories']=='North_Macedonia']
mac_df
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 4982  28/03/2020   28      3  2020     18       0         North_Macedonia
# 4983  27/03/2020   27      3  2020     24       1         North_Macedonia
# 4984  26/03/2020   26      3  2020     29       0         North_Macedonia
# 4985  25/03/2020   25      3  2020     12       0         North_Macedonia
# 4986  24/03/2020   24      3  2020     22       1         North_Macedonia
# ...          ...  ...    ...   ...    ...     ...                     ...
# 5057  04/01/2020    4      1  2020      0       0         North_Macedonia
# 5058  03/01/2020    3      1  2020      0       0         North_Macedonia
# 5059  02/01/2020    2      1  2020      0       0         North_Macedonia
# 5060  01/01/2020    1      1  2020      0       0         North_Macedonia
# 5061  31/12/2019   31     12  2019      0       0         North_Macedonia
#
#      geoId countryterritoryCode  popData2018
# 4982    MK                  MKD    2082958.0
# 4983    MK                  MKD    2082958.0
# 4984    MK                  MKD    2082958.0
# 4985    MK                  MKD    2082958.0
# 4986    MK                  MKD    2082958.0
# ...    ...                  ...          ...
# 5057    MK                  MKD    2082958.0
# 5058    MK                  MKD    2082958.0
# 5059    MK                  MKD    2082958.0
# 5060    MK                  MKD    2082958.0
# 5061    MK                  MKD    2082958.0
#
# [80 rows x 10 columns]

# %%
from sqlalchemy import create_engine
engine=create_engine('sqlite:///covid.db',echo=True)
sqlite_connection=engine.connect()

# %%
sqlite_table='Covid19'
mac_df.to_sql(sqlite_table, sqlite_connection, if_exists='fail')
# Out:
# 2023-04-07 16:53:57,899 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Covid19")
# 2023-04-07 16:53:57,901 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-07 16:53:57,903 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("Covid19")
# 2023-04-07 16:53:57,903 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-07 16:53:57,907 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Covid19" (
# 	"index" BIGINT,
# 	"dateRep" TEXT,
# 	day BIGINT,
# 	month BIGINT,
# 	year BIGINT,
# 	cases BIGINT,
# 	deaths BIGINT,
# 	"countriesAndTerritories" TEXT,
# 	"geoId" TEXT,
# 	"countryterritoryCode" TEXT,
# 	"popData2018" FLOAT
# )
#
#
# 2023-04-07 16:53:57,908 INFO sqlalchemy.engine.Engine [no key 0.00119s] ()
# 2023-04-07 16:53:57,920 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-07 16:53:57,921 INFO sqlalchemy.engine.Engine CREATE INDEX "ix_Covid19_index" ON "Covid19" ("index")
# 2023-04-07 16:53:57,922 INFO sqlalchemy.engine.Engine [no key 0.00078s] ()
# 2023-04-07 16:53:57,928 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-07 16:53:57,932 INFO sqlalchemy.engine.Engine INSERT INTO "Covid19" ("index", "dateRep", day, month, year, cases, deaths, "countriesAndTerritories", "geoId", "countryterritoryCode", "popData2018") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2023-04-07 16:53:57,932 INFO sqlalchemy.engine.Engine [generated in 0.00122s] ((4982, '28/03/2020', 28, 3, 2020, 18, 0, 'North_Macedonia', 'MK', 'MKD', 2082958.0), (4983, '27/03/2020', 27, 3, 2020, 24, 1, 'North_Macedonia', 'MK', 'MKD', 2082958.0), (4984, '26/03/2020', 26, 3, 2020, 29, 0, 'North_Macedonia', 'MK', 'MKD', 2082958.0), (4985, '25/03/2020', 25, 3, 2020, 12, 0, 'North_Macedonia', 'MK', 'MKD', 2082958.0), (4986, '24/03/2020', 24, 3, 2020, 22, 1, 'North_Macedonia', 'MK', 'MKD', 2082958.0), (4987, '23/03/2020', 23, 3, 2020, 29, 1, 'North_Macedonia', 'MK', 'MKD', 2082958.0), (4988, '22/03/2020', 22, 3, 2020, 15, 0, 'North_Macedonia', 'MK', 'MKD', 2082958.0), (4989, '21/03/2020', 21, 3, 2020, 22, 0, 'North_Macedonia', 'MK', 'MKD', 2082958.0)  ... displaying 10 of 80 total bound parameter sets ...  (5060, '01/01/2020', 1, 1, 2020, 0, 0, 'North_Macedonia', 'MK', 'MKD', 2082958.0), (5061, '31/12/2019', 31, 12, 2019, 0, 0, 'North_Macedonia', 'MK', 'MKD', 2082958.0))
# 2023-04-07 16:53:57,934 INFO sqlalchemy.engine.Engine COMMIT
# 2023-04-07 16:53:57,939 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2023-04-07 16:53:57,940 INFO sqlalchemy.engine.Engine [raw sql] ()
# 80

# %%
sqlite_connection.close()
