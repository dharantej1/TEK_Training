# %%
import pandas as pd
import numpy as np

# %%
flights=pd.read_csv("./Flights_Delay.csv")
flights=flights.loc[:,"ID":"CANCELLED"]
flights.head()
# Out:
#    ID  YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0   0  2015      3    4            3      EV           5170      N842AS
# 1   1  2015      2    2            1      MQ           3584      N646MQ
# 2   2  2015      1   27            2      B6            716      N309JB
# 3   3  2015      1   28            3      EV           4289      N14162
# 4   4  2015      2    5            4      EV           5584      N851AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  ...  ELAPSED_TIME  AIR_TIME  DISTANCE  \
# 0            CVG                 XNA  ...         129.0     108.0       562
# 1            DFW                 SPS  ...          46.0      30.0       113
# 2            JAX                 DCA  ...         110.0      91.0       634
# 3            COS                 IAH  ...         127.0     101.0       809
# 4            ATL                 AVL  ...          62.0      34.0       164
#
#    WHEELS_ON  TAXI_IN  SCHEDULED_ARRIVAL  ARRIVAL_TIME  ARRIVAL_DELAY  \
# ...

# %%
flights.isnull().sum()
# Out:
# ID                       0
# YEAR                     0
# MONTH                    0
# DAY                      0
# DAY_OF_WEEK              0
# AIRLINE                  0
# FLIGHT_NUMBER            0
# TAIL_NUMBER            404
# ORIGIN_AIRPORT           0
# DESTINATION_AIRPORT      0
# SCHEDULED_DEPARTURE      0
# DEPARTURE_TIME           0
# DEPARTURE_DELAY          0
# TAXI_OUT                 0
# WHEELS_OFF               0
# SCHEDULED_TIME           0
# ELAPSED_TIME             0
# AIR_TIME                 0
# DISTANCE                 0
# WHEELS_ON                0
# TAXI_IN                  0
# SCHEDULED_ARRIVAL        0
# ARRIVAL_TIME             0
# ARRIVAL_DELAY            0
# DIVERTED                 0
# CANCELLED                0
# dtype: int64

# %%
print(flights["DEPARTURE_TIME"].isnull().sum())
flights['DEPARTURE_TIME'].fillna((flights['DEPARTURE_TIME'].mean()), inplace=True)
flights.head()
# Out:
# 2097
#    ID  YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0   0  2015      3    4            3      EV           5170      N842AS
# 1   1  2015      2    2            1      MQ           3584      N646MQ
# 2   2  2015      1   27            2      B6            716      N309JB
# 3   3  2015      1   28            3      EV           4289      N14162
# 4   4  2015      2    5            4      EV           5584      N851AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  ...  ELAPSED_TIME  AIR_TIME  DISTANCE  \
# 0            CVG                 XNA  ...         129.0     108.0       562
# 1            DFW                 SPS  ...          46.0      30.0       113
# 2            JAX                 DCA  ...         110.0      91.0       634
# 3            COS                 IAH  ...         127.0     101.0       809
# 4            ATL                 AVL  ...          62.0      34.0       164
#
# ...

# %%
print(flights["DEPARTURE_DELAY"].isnull().sum())
flights['DEPARTURE_DELAY'].fillna((flights['DEPARTURE_DELAY'].mean()), inplace=True)
flights.head()
# Out:
# 2097
#    ID  YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0   0  2015      3    4            3      EV           5170      N842AS
# 1   1  2015      2    2            1      MQ           3584      N646MQ
# 2   2  2015      1   27            2      B6            716      N309JB
# 3   3  2015      1   28            3      EV           4289      N14162
# 4   4  2015      2    5            4      EV           5584      N851AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  ...  ELAPSED_TIME  AIR_TIME  DISTANCE  \
# 0            CVG                 XNA  ...         129.0     108.0       562
# 1            DFW                 SPS  ...          46.0      30.0       113
# 2            JAX                 DCA  ...         110.0      91.0       634
# 3            COS                 IAH  ...         127.0     101.0       809
# 4            ATL                 AVL  ...          62.0      34.0       164
#
# ...

# %%
print(flights["TAXI_OUT"].isnull().sum())
flights['TAXI_OUT'].fillna((flights['TAXI_OUT'].mean()), inplace=True)
flights.head()
# Out:
# 2134
#    ID  YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0   0  2015      3    4            3      EV           5170      N842AS
# 1   1  2015      2    2            1      MQ           3584      N646MQ
# 2   2  2015      1   27            2      B6            716      N309JB
# 3   3  2015      1   28            3      EV           4289      N14162
# 4   4  2015      2    5            4      EV           5584      N851AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  ...  ELAPSED_TIME  AIR_TIME  DISTANCE  \
# 0            CVG                 XNA  ...         129.0     108.0       562
# 1            DFW                 SPS  ...          46.0      30.0       113
# 2            JAX                 DCA  ...         110.0      91.0       634
# 3            COS                 IAH  ...         127.0     101.0       809
# 4            ATL                 AVL  ...          62.0      34.0       164
#
# ...

# %%
print(flights["WHEELS_OFF"].isnull().sum())
flights['WHEELS_OFF'].fillna((flights['WHEELS_OFF'].mean()), inplace=True)
flights.head()
# Out:
# 2134
#    ID  YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0   0  2015      3    4            3      EV           5170      N842AS
# 1   1  2015      2    2            1      MQ           3584      N646MQ
# 2   2  2015      1   27            2      B6            716      N309JB
# 3   3  2015      1   28            3      EV           4289      N14162
# 4   4  2015      2    5            4      EV           5584      N851AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  ...  ELAPSED_TIME  AIR_TIME  DISTANCE  \
# 0            CVG                 XNA  ...         129.0     108.0       562
# 1            DFW                 SPS  ...          46.0      30.0       113
# 2            JAX                 DCA  ...         110.0      91.0       634
# 3            COS                 IAH  ...         127.0     101.0       809
# 4            ATL                 AVL  ...          62.0      34.0       164
#
# ...

# %%
print(flights["ELAPSED_TIME"].isnull().sum())
flights['ELAPSED_TIME'].fillna((flights['ELAPSED_TIME'].mean()), inplace=True)
flights.head()

print(flights["AIR_TIME"].isnull().sum())
flights['AIR_TIME'].fillna((flights['AIR_TIME'].mean()), inplace=True)
flights.head()

print(flights["WHEELS_ON"].isnull().sum())
flights['WHEELS_ON'].fillna((flights['WHEELS_ON'].mean()), inplace=True)
flights.head()

print(flights["TAXI_IN"].isnull().sum())
flights['TAXI_IN'].fillna((flights['TAXI_IN'].mean()), inplace=True)
flights.head()

print(flights["ARRIVAL_TIME"].isnull().sum())
flights['ARRIVAL_TIME'].fillna((flights['ARRIVAL_TIME'].mean()), inplace=True)
flights.head()

print(flights["ARRIVAL_DELAY"].isnull().sum())
flights['ARRIVAL_DELAY'].fillna((flights['ARRIVAL_DELAY'].mean()), inplace=True)
flights.head()
# Out:
# 2302
# 2302
# 2189
# 2189
# 2189
# 2302
#    ID  YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0   0  2015      3    4            3      EV           5170      N842AS
# 1   1  2015      2    2            1      MQ           3584      N646MQ
# 2   2  2015      1   27            2      B6            716      N309JB
# 3   3  2015      1   28            3      EV           4289      N14162
# 4   4  2015      2    5            4      EV           5584      N851AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  ...  ELAPSED_TIME  AIR_TIME  DISTANCE  \
# 0            CVG                 XNA  ...         129.0     108.0       562
# 1            DFW                 SPS  ...          46.0      30.0       113
# 2            JAX                 DCA  ...         110.0      91.0       634
# 3            COS                 IAH  ...         127.0     101.0       809
# 4            ATL                 AVL  ...          62.0      34.0       164
#
# ...

# %%
print(flights["TAIL_NUMBER"].isnull().sum())
# flights['DEPARTURE_TIME'].fillna((flights['DEPARTURE_TIME'].mean()), inplace=True)
flights.fillna(np.nan)
flights
# Out:
# 404
#           ID  YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER  \
# 0          0  2015      3    4            3      EV           5170
# 1          1  2015      2    2            1      MQ           3584
# 2          2  2015      1   27            2      B6            716
# 3          3  2015      1   28            3      EV           4289
# 4          4  2015      2    5            4      EV           5584
# ...      ...   ...    ...  ...          ...     ...            ...
# 55995  55995  2015      2    4            3      B6           1567
# 55996  55996  2015      1   17            6      AA           1113
# 55997  55997  2015      1   17            6      US            661
# 55998  55998  2015      1   13            2      DL           1318
# 55999  55999  2015      2   25            3      US            499
#
#       TAIL_NUMBER ORIGIN_AIRPORT DESTINATION_AIRPORT  ...  ELAPSED_TIME  \
# 0          N842AS            CVG                 XNA  ...    129.000000
# ...

# %%
flights.to_csv("Flights_Delay_cleaned.csv")
